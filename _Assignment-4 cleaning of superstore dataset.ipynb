# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\santy\Documents\Superstore_Dataset.csv",encoding='latin1')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688  12/06/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9993    9994  CA-2017-119914  04/05/2017  09/05/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head(20)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688  12/06/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# 5        6  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 6        7  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 7        8  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 8        9  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 9       10  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 10      11  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 11      12  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 12      13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
cato=df.dtypes[df.dtypes=="object"].index

# %%
cato
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df[cato].describe()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# count             9994        9994        9994            9994        9994
# unique            5009        1237        1334               4         793
# top     CA-2017-100111  05/09/2016  12/16/2015  Standard Class    WB-21850
# freq                14          38          35            5968          37
#
#         Customer Name   Segment        Country           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
#
#        Region       Product ID         Category Sub-Category     Product Name
# count    9994             9994             9994         9994             9994
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# loss/gain        0
# dtype: int64

# %%
new_region=pd.Categorical(df["Region"],ordered=True)
new_region=new_region.rename_categories(["Region1","Region2","Region3","Region4"])
new_region.describe()
# Out:
#             counts     freqs
# categories
# Region1       2323  0.232439
# Region2       2848  0.284971
# Region3       1620  0.162097
# Region4       3203  0.320492

# %%
df["Region"].describe()
# Out:
# count     9994
# unique       4
# top       West
# freq      3203
# Name: Region, dtype: object

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
print(df['Region'].value_counts())
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df.head(20)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688  12/06/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# 5        6  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 6        7  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 7        8  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 8        9  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 9       10  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 10      11  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 11      12  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 12      13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# ...

# %%
print(df['Segment'].value_counts())
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
print(df['City'].value_counts())
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
print(df['Category'].value_counts())
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
print(df['Sub-Category'].value_counts())
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.scatter(df['Quantity'],df['Discount'],color="red")
plt.title('quantity vs discount')
plt.xlabel('quantity')
plt.ylabel('discount')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(df['Quantity'], labels = df['Quantity'])
plt.show()

# %%
import seaborn as sns

# %%
sns.scatterplot(x="Sales", y="Quantity", data=df);

# %%
sns.lmplot(x="Sales", y="Quantity",hue="Region", data=df);

# %%
sns.lmplot(x="Sales", y="Quantity",hue="Segment", data=df);

# %%
sns.lmplot(x="Sales", y="Quantity",hue="City", data=df);

# %%
sns.lmplot(x="Sales", y="Quantity",hue="Category", data=df);

# %%
sns.lmplot(x="Sales", y="Quantity",hue="Sub-Category", data=df);

# %%
df.head(20)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688  12/06/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# 5        6  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 6        7  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 7        8  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 8        9  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 9       10  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 10      11  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 11      12  CA-2014-115812  09/06/2014   6/14/2014  Standard Class
# 12      13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# ...

# %%
plt.boxplot(df["Quantity"])
plt.show()

# %%
plt.boxplot(df["Discount"])
plt.show()

# %%
x=df["Sub-Category"]
y=df["Quantity"]
plt.bar(x,y)
plt.title("Sub-category vs quantity")
plt.xlabel('Sub-category')
plt.xticks(rotation=45)
plt.ylabel('Quantity')
plt.show()

# %%
df.corr()
round(df.corr(),2)
# Out:
#              Row ID  Postal Code  Sales  Quantity  Discount  Profit
# Row ID         1.00         0.01  -0.00     -0.00      0.01    0.01
# Postal Code    0.01         1.00  -0.02      0.01      0.06   -0.03
# Sales         -0.00        -0.02   1.00      0.20     -0.03    0.48
# Quantity      -0.00         0.01   0.20      1.00      0.01    0.07
# Discount       0.01         0.06  -0.03      0.01      1.00   -0.22
# Profit         0.01        -0.03   0.48      0.07     -0.22    1.00

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
